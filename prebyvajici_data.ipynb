# %%
import pandas as pd

path = "nlsy.csv"
df = pd.read_csv(path)
df.head(6)
# Out:
#    GAD-7 Score  Case ID  Sample ID   Race Sex  CESD_SCORE_7_ITEM  \
# 0           -4        1          5  White   F                NaN
# 1            2        2          5  White   F                0.0
# 2           -4        3          5  White   F                2.0
# 3           -4        4          5  White   F               13.0
# 4           -4        5          1  White   M                NaN
# 5            5        6          1  White   M                3.0
#
#    Hours_worked_last_year
# 0                     NaN
# 1                  1820.0
# 2                  2312.0
# 3                  2285.0
# 4                     NaN
# 5                  2080.0
